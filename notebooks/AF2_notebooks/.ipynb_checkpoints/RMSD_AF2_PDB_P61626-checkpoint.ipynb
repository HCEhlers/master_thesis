# %% [raw]
# ---
# title: "Comparing AF2 RMSD with PDB RMSD"
# execute:
#   enabled: true
# format: pdf
# ---

# %%
import pandas as pd
import numpy as np
import os, sys
import matplotlib.pyplot as plt
from matplotlib.pyplot import gcf
import seaborn as sns
import scipy.stats
from scipy.stats import gaussian_kde
from matplotlib import cm
from matplotlib.colors import Normalize
from scipy import stats
import urllib.request
import mdtraj as md
import scipy as sp
import math
sns.set_style("darkgrid")

# %%
#Use this method if running from the notebooks folder otherwise comment out the following change:
os.chdir('../..')

cwd = os.getcwd()
DATA_PATH_ROOT = cwd
DATA_PATH_MUT_AF2 = DATA_PATH_ROOT + '/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut/'
DATA_PATH_MUT_PDB = DATA_PATH_ROOT + '/data/results_rmsd/results_rmsd_pdb/results_rmsd_P61626_mut/'
DATA_PATH_PDB = DATA_PATH_ROOT + '/data/arodz12/pdbs_P61626/'
DATA_PATH_PDB_WT= DATA_PATH_ROOT + '/data/arodz12/pdbs_wt_P61626/'
DATA_PATH_AF2 = DATA_PATH_ROOT + '/data/results_af2/P61626/P61626_default'
DATA_PATH_MUT_2_MUT = DATA_PATH_ROOT + '/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2mut/'
DATA_PATH_MUT_2_WT = DATA_PATH_ROOT + '/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/'

# PDBs in the dataset
arodz_pdbs = ['1gb5', '1gb6', '1gb7', '1gb8', '1gb9', '1gbo', '1gbw', '1gbx', '1gby', '1gbz', '1gfh', '1gfj', '1gfk', '1gfr', '1gft', '1gfu','1gfv', '1inu', '1lhh', '1lhi', '1lhj', '1lhk', '1lhl', '1oub','1ouc', '1oud', '1oue', '1ouh', '1oui', '1ouj', '1wqm', '1wqn','1wqo', '1wqp', '1wqq', '1wqr', '1yam', '1yan', '1yao', '1yap','1yaq', '2hea', '2heb', '2hec', '2hed', '2hee', '2hef']

# %%
def get_chi1_angles(pdb):
        pdb = md.load_pdb(pdb)
        topology = pdb.topology
        table, bonds = topology.to_dataframe()
        ch1_pos, ch1_rad = md.compute_chi1(pdb)[0], md.compute_chi1(pdb)[1]
        chi_1_angles = np.degrees(ch1_rad)
        res = [table['resName'][ch1_pos[res][-1]] for res in range(len(ch1_pos))]
        n = [table['resSeq'][ch1_pos[res][-1]] for res in range(len(ch1_pos))]
        pos = [list(a) for a in zip(n,res)]
        return chi_1_angles, pos

def conv_to_np_arr_new(list_angles):
    mean_angles = np.array([])
    max_val = max(len(elem) for elem in list_angles)
    print(max_val)
    for i in range(len(list_angles)):
        len_ls = len(list_angles[i])
        if len_ls < max_val:
            arr_2nan = np.empty((1,max_val-len_ls))
            arr_2nan[:] = 0
            list_angles[i] = np.append(list_angles[i],arr_2nan)
        #for j in range(len_ls):
            #if list_angles[i][j] <= -120:
                #list_angles[i][j] += 360
    degs =  np.vstack((list_angles))
    #print('here here: ', degs[degs < -120])
    av_sin = np.mean(np.sin(degs * np.pi / 180.),axis=0)
    av_cos = np.mean(np.cos(degs * np.pi / 180.),axis=0)
    mean_angles = np.rad2deg(np.arctan2(av_sin,av_cos))
    mean_angles[mean_angles <= -120] += 360
    return list_angles, mean_angles

def conv_to_np_arr_old(list_angles):
    max_val = max(len(elem) for elem in list_angles)
    for i in range(len(list_angles)):
        len_ls = len(list_angles[i])
        if len_ls < max_val:
            arr_2nan = np.empty((1,max_val-len_ls))
            arr_2nan[:] = 0
            list_angles[i] = np.append(list_angles[i],arr_2nan)
    return list_angles

# Correlation of Vector
def correlations_vector(score1, score2):
    # Declaring y and x to append mave_data comp_data, respectively.
    y=[]; x=[]
    # Looping through NaNs and inly appending non NaNs to y and x
    for i in range(score1.shape[0]):
        if np.isnan(score1[i]) or np.isnan(score2[i]):
            pass
        else:
            x.append(float(score1[i]))
            y.append(float(score2[i]))
    # Converting to np arrays and calculating pearson and spearman correalation.
    x=np.array(x)
    y=np.array(y)
    r=sp.stats.pearsonr(x,y)
    s,p=sp.stats.spearmanr(x,y)
    print("Pearson's correlation coefficient between data: ",abs(r[0]))
    print("Spearman's correlation coefficient bewteen data: " ,abs(s))

    return [abs(r[0]),abs(s)]

# Correlation of Matrix
def correlations_matrix(score1, score2):
    # Declaring y and x to append mave_data comp_data, respectively.
    y=[]; x=[]

    # Looping through NaNs and inly appending non NaNs to y and x
    for i in range(score1.shape[0]):
        for j in range(score1.shape[1]):
            if np.isnan(score1[i,j]) or np.isnan(score2[i,j]):
                pass
            else:
                x.append(float(score1[i,j]))
                y.append(float(score2[i,j]))
    # Converting to np arrays and calculating pearson and spearman correalation.
    x=np.array(x)
    y=np.array(y)
    r=sp.stats.pearsonr(x,y)
    s,p=sp.stats.spearmanr(x,y)
    print("Pearson's correlation coefficient between data: ",abs(r[0]))
    print("Spearman's correlation coefficient bewteen data: " ,abs(s))

    return [abs(r[0]),abs(s)]

# Load RMSDs from file
def load_rmsd(path, pdbs):
    dir_list = sorted(os.listdir(path))
    rmsd_list = np.zeros(len(dir_list))
    mut_list = [0]*len(dir_list)
    for i in range(len(dir_list)):
        df = pd.read_csv(path + dir_list[i])['rmsd'][0]
        rmsd_list[i] = df
        if 'af2' in path:
            df1 = pd.read_csv(path + dir_list[i])['mut'][0]
            mut_list[i] = df1
    return rmsd_list, mut_list

# Load torsion angles for PDBs
def compile_angles_pdb(path):
    filenames = list()
    dir_list = sorted(os.listdir(path))
    angles_list = list()
    pos_list = list()
    for i in range(1,len(dir_list)):
        chi1_angle, pos = get_chi1_angles(path + dir_list[i])
        chi1_angle = chi1_angle.squeeze()
        angles_list.append(chi1_angle)
        filenames.append(dir_list[i])
        pdb = md.load_pdb(path + dir_list[i])
        topology = pdb.topology
        table, bonds = topology.to_dataframe()
        pos_list.append(pos)
    return angles_list, filenames, pos_list

# Load torsion angles for af 2
def compile_angles_af2(path, pdbs):
    filenames = list()
    dir_list = sorted(os.listdir(path))
    angles_list = list()
    pos_list = list()
    plddt_list = list()
    for k in range(len(dir_list)):
        for pdb in pdbs:
            if pdb in dir_list[k]:
                tmp_dir_list = os.listdir(path + '/' + dir_list[k])    
                pdb_file = [file for file in  tmp_dir_list if 'rank_1' in file and '.pdb' in file]
                # Read pLDDT scores
                plddt_file = [file for file in  tmp_dir_list if 'rank_1' in file and '.json' in file]
                plddt_df = pd.read_json(path + '/' + dir_list[k] + '/' + plddt_file[0])
                plddt_ls = plddt_df['plddt'].tolist()
                plddt_list.append(plddt_ls)
                filenames.append(pdb_file[0])
                chi1_angle, pos = get_chi1_angles(path + '/' + dir_list[k] + '/' + pdb_file[0])
                chi1_angle = chi1_angle.squeeze()
                angles_list.append(chi1_angle)
                pos_list.append(pos)
    return angles_list, filenames, pos_list, plddt_list

def circ_meanscatter_plot(x_ls,y_ls, plddt):
    X, X_means = conv_to_np_arr_new(x_ls)
    Y, Y_means = conv_to_np_arr_new(y_ls)
    
    #fig = plt.figure()
    plddt_mean = np.mean(plddt_indexed,axis=0)
    #kernel = gaussian_kde(plddt_mean)
    #kde = kernel.evaluate(plddt_mean)
    #norm = Normalize(vmin=kde.min(), vmax=kde.max())
    #colors = plt.cm.ScalarMappable(norm=norm, cmap='GnBu').to_rgba(kde)
    colormap = plt.cm.get_cmap('GnBu') # 'plasma' or 'viridis'
    colors = colormap(plddt_mean)    
    
    plt.title('P61626',fontsize=12)
    plt.xlabel('$\chi_1$ AF2 [$^\circ$]',fontsize=12)
    plt.ylabel('$\chi_1$ X-ray [$^\circ$]',fontsize=12)
    plt.xlim(-120,250)
    plt.ylim(-120,250)
    trend = np.polyfit(X_means,Y_means,1)
    trendpoly = np.poly1d(trend) 
    scatter_plot = plt.scatter(X_means, Y_means, vmin=0, vmax=X_means.max(), c=colors)
    sm = plt.cm.ScalarMappable(cmap=colormap)
    sm.set_clim(vmin=0, vmax=100)
    plt.colorbar(sm, label='pLDDT')
    plt.plot(X_means,trendpoly(X_means), c='black', label = 'ρ = 0.86')
    plt.legend(fontsize=14, loc="upper left")
    plt.savefig(DATA_PATH_ROOT + "/notebooks/figs/chi1_plot_P61626_wt.pdf")
    
    print(X_means.shape, Y_means.shape)
    return correlations_vector(X_means, Y_means)

def scatter_plot(x_ls,y_ls):
    X=np.stack(conv_to_np_arr_old(x_ls))
    Y=np.stack(conv_to_np_arr_old(y_ls))
    print(np.nanmean(X, axis=0))
    values = np.vstack((np.nanmean(X, axis=0), np.nanmean(Y, axis=0)))
    kernel = gaussian_kde(values)
    kde = kernel.evaluate(values)
    norm = Normalize(vmin=kde.min(), vmax=kde.max())
    colors = cm.ScalarMappable(norm=norm, cmap='viridis_r').to_rgba(kde)
    plt.title('P61626',fontsize=12)
    plt.xlabel('$\chi_1$ AF2 [$^\circ$]',fontsize=12)
    plt.ylabel('$\chi_1$ X-ray [$^\circ$]',fontsize=12)

    trend = np.polyfit(np.nanmean(X, axis=0),np.nanmean(Y, axis=0),1)
    trendpoly = np.poly1d(trend) 
    plt.scatter(np.nanmean(X, axis=0), np.nanmean(Y, axis=0), c=colors)
    plt.plot(np.nanmean(X, axis=0),trendpoly(np.nanmean(X, axis=0)), c='black', label = 'ρ = 0.63')
    plt.legend(fontsize=14, loc="upper left")
    plt.savefig(DATA_PATH_ROOT + "/notebooks/figs/chi1_plot_P61626.png", dpi=1200)
    
    return correlations_matrix(X, Y)

def mean_plddt(path, pdbs):
    filenames = list()
    dir_list = sorted(os.listdir(path))
    plddt_mean_ls = list()
    for k in range(len(dir_list)):
        for pdb in pdbs:
            if pdb in dir_list[k]:
                tmp_dir_list = os.listdir(path + '/' + dir_list[k])    
                pdb_file = [file for file in  tmp_dir_list if 'rank_1' in file and '.pdb' in file]
                # Read pLDDT scores
                plddt_file = [file for file in  tmp_dir_list if 'rank_1' in file and '.json' in file]
                print(plddt_file[0])
                plddt_df = pd.read_json(path + '/' + dir_list[k] + '/' + plddt_file[0])
                plddt_ls = plddt_df['plddt'].mean()
                plddt_mean_ls.append(plddt_ls)
                filenames.append(pdb_file[0])
    mean_arr = np.asarray(plddt_mean_ls)
    mean = np.mean(plddt_mean_ls)
    return mean

# %%
mut_2_mut_rmsd_list, mut = load_rmsd(DATA_PATH_MUT_2_MUT, arodz_pdbs)
mut_2_wt_rmsd_list, mut = load_rmsd(DATA_PATH_MUT_2_WT, arodz_pdbs)

# Get RMSDs
af2_rmsd_list, mut = load_rmsd(DATA_PATH_MUT_AF2, arodz_pdbs)
pdb_rmsd_list, _ = load_rmsd(DATA_PATH_MUT_PDB, arodz_pdbs)

# Get chi 1 angles
chi_1_pdb, filenames_pdb, pos_pdb = compile_angles_pdb(DATA_PATH_PDB)
chi_1_af2, filenames_af2, pos_af2, plddt = compile_angles_af2(DATA_PATH_AF2,arodz_pdbs)

chi_1_pdb_wt, filenames_pdb_wt, pos_pdb_wt = compile_angles_pdb(DATA_PATH_PDB_WT)
chi_1_pdb_wt_ls = []
for i in range(len(chi_1_pdb_wt)):
    if 106-len(chi_1_pdb_wt[i]) !=0 and len(chi_1_pdb_wt[i]) == 105:
        chi_1_pdb_wt[i] = np.append(chi_1_pdb_wt[i],np.zeros(106-len(chi_1_pdb_wt[i])))
        chi_1_pdb_wt_ls.append(chi_1_pdb_wt[i])

# %%
mean_plddt_r = mean_plddt(DATA_PATH_AF2,arodz_pdbs)
# Out:
# P61626_1gb5_32663_unrelaxed_rank_1_model_5_scores.json
# P61626_1gb6_3db01_unrelaxed_rank_1_model_5_scores.json
# P61626_1gb7_34253_unrelaxed_rank_1_model_5_scores.json
# P61626_1gb8_29aa4_unrelaxed_rank_1_model_5_scores.json
# P61626_1gb9_b5251_unrelaxed_rank_1_model_5_scores.json
# P61626_1gbo_8a7a6_unrelaxed_rank_1_model_5_scores.json
# P61626_1gbw_c9d43_unrelaxed_rank_1_model_5_scores.json
# P61626_1gbx_efb59_unrelaxed_rank_1_model_5_scores.json
# P61626_1gby_02d41_unrelaxed_rank_1_model_5_scores.json
# P61626_1gbz_8966e_unrelaxed_rank_1_model_5_scores.json
# P61626_1gfh_1e15b_unrelaxed_rank_1_model_5_scores.json
# P61626_1gfj_09f32_unrelaxed_rank_1_model_5_scores.json
# P61626_1gfk_00cf7_unrelaxed_rank_1_model_5_scores.json
# P61626_1gfr_ce259_unrelaxed_rank_1_model_5_scores.json
# P61626_1gft_b1c92_unrelaxed_rank_1_model_5_scores.json
# P61626_1gfu_4730f_unrelaxed_rank_1_model_5_scores.json
# P61626_1gfv_135dd_unrelaxed_rank_1_model_5_scores.json
# P61626_1inu_3a3c9_unrelaxed_rank_1_model_5_scores.json
# P61626_1lhh_3a3d2_unrelaxed_rank_1_model_5_scores.json
# P61626_1lhi_a34c3_unrelaxed_rank_1_model_5_scores.json
# P61626_1lhj_28e9b_unrelaxed_rank_1_model_5_scores.json
# P61626_1lhk_b7ba9_unrelaxed_rank_1_model_5_scores.json
# P61626_1lhl_2d062_unrelaxed_rank_1_model_5_scores.json
# P61626_1oub_fcab1_unrelaxed_rank_1_model_5_scores.json
# P61626_1ouc_33d6f_unrelaxed_rank_1_model_5_scores.json
# P61626_1oud_5e5e7_unrelaxed_rank_1_model_5_scores.json
# P61626_1oue_67f0f_unrelaxed_rank_1_model_5_scores.json
# P61626_1ouh_95b0b_unrelaxed_rank_1_model_5_scores.json
# P61626_1oui_75b31_unrelaxed_rank_1_model_5_scores.json
# P61626_1ouj_ca456_unrelaxed_rank_1_model_5_scores.json
# P61626_1wqm_98012_unrelaxed_rank_1_model_5_scores.json
# P61626_1wqn_f271b_unrelaxed_rank_1_model_5_scores.json
# P61626_1wqo_80e15_unrelaxed_rank_1_model_5_scores.json
# P61626_1wqp_4c0c3_unrelaxed_rank_1_model_5_scores.json
# P61626_1wqq_80b67_unrelaxed_rank_1_model_5_scores.json
# P61626_1wqr_da59b_unrelaxed_rank_1_model_5_scores.json
# P61626_1yam_5865b_unrelaxed_rank_1_model_5_scores.json
# P61626_1yan_2f240_unrelaxed_rank_1_model_5_scores.json
# P61626_1yao_b3c89_unrelaxed_rank_1_model_5_scores.json
# P61626_1yap_991ac_unrelaxed_rank_1_model_5_scores.json
# P61626_1yaq_d4469_unrelaxed_rank_1_model_5_scores.json
# P61626_2hea_07ef1_unrelaxed_rank_1_model_5_scores.json
# P00720_2heb_12db8_unrelaxed_rank_1_model_5_scores.json
# P00720_2hec_f8107_unrelaxed_rank_1_model_5_scores.json
# P00720_2hed_d9d6a_unrelaxed_rank_1_model_5_scores.json
# P00720_2hee_65a71_unrelaxed_rank_1_model_5_scores.json
# P61626_2hef_3ae7e_unrelaxed_rank_1_model_5_scores.json

# %%
pdb_rmsd_list[pdb_rmsd_list > 0.45]
def load_rmsd(path, pdbs):
    dir_list = sorted(os.listdir(path))
    rmsd_list = np.zeros(len(dir_list))
    mut_list = [0]*len(dir_list)
    for i in range(len(dir_list)):
        df = pd.read_csv(path + dir_list[i])['rmsd'][0]
        if df > 0.45:
            print(path + dir_list[i])
    return 0
load_rmsd(DATA_PATH_MUT_PDB, arodz_pdbs)
# Out:
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_pdb/results_rmsd_P61626_mut/rmsd_mut_P61626_1gbz.csv
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_pdb/results_rmsd_P61626_mut/rmsd_mut_P61626_1gft.csv
# 0

# %%
round(mean_plddt_r,3)
# Out:
# 98.414

# %%
# RMSD plot: AF2 vs. PDB
plt.ylabel('Variant RMSD [Å]',fontsize=8)
plt.xlabel('Wild-type RMSD [Å]',fontsize=8)

plt.scatter(mut_2_wt_rmsd_list, mut_2_mut_rmsd_list)
plt.xlim(0.3,0.75)
plt.ylim(0.3,0.75)
plt.savefig(DATA_PATH_ROOT + "/notebooks/figs/P61626_dis_scatter.png", dpi=1200)
correlations_vector(mut_2_wt_rmsd_list, mut_2_mut_rmsd_list)
# Out:
# Pearson's correlation coefficient between data:  0.8757960275067453
# Spearman's correlation coefficient bewteen data:  0.4009019426456984
# [0.8757960275067453, 0.4009019426456984]

# %%
chi_1_af2_mean = []
chi_1_pdb_mean = []
rsn_N = list()
for i in range(len(filenames_af2)):
    rsn_N.append(mut[i])
    chi_1_af2_mean.append(np.mean(chi_1_af2[i]))
    chi_1_pdb_mean.append(np.mean(chi_1_pdb[i]))

print(rsn_N[1])
print(filenames_af2[0])

for i in range(len(pos_af2[46])):
    if pos_af2[46][i][0] == int(rsn_N[46][3:-3]):
        print(i)

chi_1_mut_af2 = np.asarray([chi_1_af2[1][59],chi_1_af2[3][59],chi_1_af2[4][59],chi_1_af2[6][87], chi_1_af2[7][87], chi_1_af2[8][87], chi_1_af2[9][87], chi_1_af2[10][59],
                chi_1_af2[11][59], chi_1_af2[12][59], chi_1_af2[13][59],chi_1_af2[14][87],chi_1_af2[15][87],chi_1_af2[16][87],chi_1_af2[17][87],chi_1_af2[18][87],
                chi_1_af2[21][73],chi_1_af2[22][38],chi_1_af2[30][100], chi_1_af2[31][16], chi_1_af2[32][30],chi_1_af2[33][36],chi_1_af2[34][43],chi_1_af2[35][51],chi_1_af2[36][84],chi_1_af2[37][18],chi_1_af2[38][44],
                chi_1_af2[39][47],chi_1_af2[40][72]], dtype=np.float32)
chi_1_mut_pdb = np.asarray([chi_1_pdb[1][59],chi_1_pdb[3][59],chi_1_pdb[4][59],chi_1_pdb[6][87],chi_1_pdb[7][87],chi_1_pdb[8][87], chi_1_pdb[9][87], chi_1_pdb[10][59],
                chi_1_pdb[11][59],chi_1_pdb[12][59],chi_1_pdb[13][59],chi_1_pdb[14][87],chi_1_pdb[15][87],chi_1_pdb[16][87],chi_1_pdb[17][87],chi_1_pdb[18][87],
                chi_1_pdb[21][73],chi_1_pdb[22][38],chi_1_pdb[30][100],chi_1_pdb[31][16],chi_1_pdb[32][30],chi_1_pdb[33][36],chi_1_pdb[34][43],chi_1_pdb[35][51],chi_1_pdb[36][84],chi_1_pdb[37][18],chi_1_pdb[38][44],
                chi_1_pdb[39][47],chi_1_pdb[40][72]], dtype=np.float32)

chi_1_mut_af2[chi_1_mut_af2 <= -120] += 360
chi_1_mut_pdb[chi_1_mut_pdb <= -120] += 360

# Looked into std for specific mutant but only unique mutations exists
#std_74_V74I = np.std([chi_1_af2[1][59],chi_1_af2[3][59]])
#e = np.ones((1,29))*np.std([chi_1_af2[1][59],chi_1_af2[3][59]])
#print(len(chi_1_mut_pdb))
#print(rsn_N)
#from collections import Counter
#Counter(rsn_N)
# Out:
# ['V74I']
# P61626_1gb5_32663_unrelaxed_rank_1_model_5.pdb

# %%
plt.title('P61626',fontsize=8)
plt.ylabel('X-ray $\chi_1$ [$^\circ$]',fontsize=8)
plt.xlabel('AF2 $\chi_1$ [$^\circ$]',fontsize=8)
trend = np.polyfit(chi_1_mut_af2,chi_1_mut_pdb,1)
trendpoly = np.poly1d(trend) 
plt.scatter(chi_1_mut_af2, chi_1_mut_pdb, c=chi_1_mut_af2, cmap='rainbow')
#plt.errorbar(chi_1_mut_af2, chi_1_mut_pdb, xerr=e, yerr = None, ls='none') 

plt.plot(chi_1_mut_af2,trendpoly(chi_1_mut_af2), c='black', label = 'ρ = 0.51')
plt.legend(fontsize=14)
plt.savefig(DATA_PATH_ROOT + '/notebooks/figs/chi1_mut_rainbow_P61626.png', dpi=1200, bbox_inches = 'tight')

correlations_vector(np.array(chi_1_mut_af2),np.array(chi_1_mut_pdb))
# Out:
# Pearson's correlation coefficient between data:  0.5067773447460812
# Spearman's correlation coefficient bewteen data:  0.4871921182266009
# [0.5067773447460812, 0.4871921182266009]

# %%
plt.title('P61626',fontsize=8)
plt.ylabel('X-ray $\chi_1$ [$^\circ$]',fontsize=8)
plt.xlabel('AF2 $\chi_1$ [$^\circ$]',fontsize=8)
trend = np.polyfit(chi_1_mut_af2,chi_1_mut_pdb,1)
trendpoly = np.poly1d(trend) 
plt.scatter(chi_1_mut_af2, chi_1_mut_pdb)
plt.xlim(-120,250)
plt.ylim(-120,250)
plt.plot(chi_1_mut_af2,trendpoly(chi_1_mut_af2), c='black', label = 'ρ = 0.51')
plt.legend(fontsize=14, )
plt.savefig(DATA_PATH_ROOT + '/notebooks/figs/chi1_mut_P61626.png', dpi=1200, bbox_inches = 'tight')

correlations_vector(np.array(chi_1_mut_af2),np.array(chi_1_mut_pdb))
# Out:
# Pearson's correlation coefficient between data:  0.5067773447460812
# Spearman's correlation coefficient bewteen data:  0.4871921182266009
# [0.5067773447460812, 0.4871921182266009]

# %%
# Same plot as above but for wt
chi_1_angles_wt, pos_wt = get_chi1_angles('/Users/holger/Desktop/master_thesis/data/arodz12/pdbs_P61626/0_1lz1.pdb')

chi_1_angles_wt = conv_to_np_arr_old(chi_1_angles_wt)


chi_1_mut_af2 = np.asarray([chi_1_af2[1][59],chi_1_af2[3][59],chi_1_af2[4][59],chi_1_af2[6][87], chi_1_af2[7][87], chi_1_af2[8][87], chi_1_af2[9][87], chi_1_af2[10][59],
                chi_1_af2[11][59], chi_1_af2[12][59], chi_1_af2[13][59],chi_1_af2[14][87],chi_1_af2[15][87],chi_1_af2[16][87],chi_1_af2[17][87],chi_1_af2[18][87],
                chi_1_af2[21][73],chi_1_af2[22][38],chi_1_af2[30][100], chi_1_af2[31][16], chi_1_af2[32][30],chi_1_af2[33][36],chi_1_af2[34][43],chi_1_af2[35][51],chi_1_af2[36][84],chi_1_af2[37][18],chi_1_af2[38][44],
                chi_1_af2[39][47],chi_1_af2[40][72]], dtype=np.float32)
chi_1_mut_wt = np.asarray([chi_1_angles_wt[0][59],chi_1_angles_wt[0][59],chi_1_angles_wt[0][87],chi_1_angles_wt[0][87],chi_1_angles_wt[0][87],chi_1_angles_wt[0][87], chi_1_angles_wt[0][87], chi_1_angles_wt[0][59],
                chi_1_angles_wt[0][59],chi_1_angles_wt[0][59],chi_1_angles_wt[0][59],chi_1_angles_wt[0][87],chi_1_angles_wt[0][87],chi_1_angles_wt[0][87],chi_1_angles_wt[0][87],chi_1_angles_wt[0][87],
                chi_1_angles_wt[0][73],chi_1_angles_wt[0][38],chi_1_angles_wt[0][100],chi_1_angles_wt[0][16],chi_1_angles_wt[0][30],chi_1_angles_wt[0][36],chi_1_angles_wt[0][43],chi_1_angles_wt[0][51],chi_1_angles_wt[0][84],chi_1_angles_wt[0][18],chi_1_angles_wt[0][44],
                chi_1_angles_wt[0][47],chi_1_angles_wt[0][72]], dtype=np.float32)

chi_1_mut_af2[chi_1_mut_af2 <= -120] += 360
chi_1_mut_wt[chi_1_mut_wt <= -120] += 360

plt.title('P61626',fontsize=8)
plt.ylabel('X-ray $\chi_1$ [$^\circ$]',fontsize=8)
plt.xlabel('AF2 $\chi_1$ [$^\circ$]',fontsize=8)
trend = np.polyfit(chi_1_mut_af2,chi_1_mut_wt,1)
trendpoly = np.poly1d(trend) 
plt.scatter(chi_1_mut_af2, chi_1_mut_wt, c=chi_1_mut_af2, cmap='rainbow')
plt.plot(chi_1_mut_af2,trendpoly(chi_1_mut_af2), c='black', label = 'ρ = 0.1')
plt.legend(fontsize=14)
plt.savefig(DATA_PATH_ROOT + '/notebooks/figs/chi1_wt_rainbow_P61626.png', dpi=1200, bbox_inches = 'tight')
correlations_vector(np.array(chi_1_mut_af2),np.array(chi_1_mut_wt))
# Out:
# Pearson's correlation coefficient between data:  0.21256184646242088
# Spearman's correlation coefficient bewteen data:  0.25513186554697304
# [0.21256184646242088, 0.25513186554697304]

# %%
# Do this for all
plddt_idx = list()
for i in range(len(pos_af2)):
    tmp = np.asarray([pos_af2[0][i][0] for i in range(len(pos_af2[0]))])
    plddt_idx.append(tmp)
plddt_idx = np.vstack(np.asarray(plddt_idx)-1)
plddt = np.asarray(plddt)
plddt_indexed = [np.append(plddt[i][plddt_idx[i]],np.array([np.mean(plddt_idx[i],axis=0),np.mean(plddt_idx[i],axis=0)])) for i in range(len(plddt))]

plddt_indexed = np.vstack(plddt_indexed)

plddt_indexed.shape
# Out:
# (47, 106)

# %%
# Scatter plot chi_1_af2 vs. chi_1_pdb
#circ_meanscatter_plot(chi_1_af2, chi_1_pdb,plddt)
circ_meanscatter_plot(chi_1_af2,chi_1_pdb_wt_ls, plddt)
# Out:
# 106
# 106
# /var/folders/38/bl4yf01j4jx6h6m2ctkbjd3r0000gn/T/ipykernel_60694/2088241926.py:164: MatplotlibDeprecationWarning: Auto-removal of grids by pcolor() and pcolormesh() is deprecated since 3.5 and will be removed two minor releases later; please call grid(False) first.
#   plt.colorbar(sm, label='pLDDT')
# (106,) (106,)
# Pearson's correlation coefficient between data:  0.8555775283803888
# Spearman's correlation coefficient bewteen data:  0.7384084439630199
# [0.8555775283803888, 0.7384084439630199]

# %%
X=np.stack(conv_to_np_arr_old(chi_1_af2)).reshape(-1,106)
Y=np.stack(conv_to_np_arr_old(chi_1_pdb)).reshape(-1,106)

#dat = np.hstack((X.reshape(-1,47), Y.reshape(-1,47)))
dat = np.vstack((Y,X)).T
filenames_combined = filenames_pdb+filenames_af2
names = filenames_combined

filenames_combined = ["AF2_" + name[7:11] if name.startswith("P61626") or name.startswith("P00720") else "PDB_"+ name[0:4] for name in names]
df_test = pd.DataFrame(dat, index=[i for i in range(106)], columns=filenames_combined)


dataset = ["AF2" if name.startswith("P61626") or name.startswith("P00720") else "X-ray" for name in names]
a = {'AF2': 'lightgray', 'X-ray': 'lightblue'}
colors = lambda x: a[x]
col_colors = list(map(colors, dataset))
sns.set(font_scale = 0.60)
cm=sns.clustermap(df_test,
               method='average',
               cbar_pos = (1, .20, .03, .45),
               yticklabels=False,
               col_colors=col_colors,
               xticklabels=True,
               #standard_scale=1,
               annot_kws={"size": 1},
               cmap='viridis',
               vmin=-180,
               vmax=180)

# Add legends
for label in ['X-ray', 'AF2']:
    cm.ax_col_dendrogram.bar(0, 0, color=a[label], label=label, linewidth=0);
l1 = cm.ax_col_dendrogram.legend(title='Structure', loc="center", ncol=5, bbox_to_anchor=(0.1, 0.89), bbox_transform=gcf().transFigure, prop={'size': 10})

plt.savefig(DATA_PATH_ROOT + '/notebooks/figs/clustermap_chi1_P61626.png', dpi=1200, bbox_inches = 'tight')

# %%
# RMSD plot: AF2 vs. PDB
plt.ylabel('Experimental RMSD [Å]',fontsize=8)
trend = np.polyfit(af2_rmsd_list,pdb_rmsd_list,1)
trendpoly = np.poly1d(trend) 
plt.scatter(af2_rmsd_list, pdb_rmsd_list)
plt.plot(af2_rmsd_list,trendpoly(af2_rmsd_list), c='black')
plt.savefig(DATA_PATH_ROOT + "/notebooks/figs/rmsd_distribution_P61626.png", dpi=1200)
correlations_vector(af2_rmsd_list, pdb_rmsd_list)
# Out:
# Pearson's correlation coefficient between data:  0.2206266173321082
# Spearman's correlation coefficient bewteen data:  0.3464384828862165
# [0.2206266173321082, 0.3464384828862165]

# %%
# RMSDs for AF2 wt compared to 1lz1_AF2
DATA_PATH = DATA_PATH_ROOT + '/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_wt/'
dir_list = os.listdir(DATA_PATH)
rmsd_list_af2_wt = np.zeros(len(dir_list))

for i in range(len(dir_list)):
    df = pd.read_csv(DATA_PATH + dir_list[i])['rmsd'][0]
    rmsd_list_af2_wt[i] = df
af2_wt_mean = np.mean(rmsd_list_af2_wt)

# %%
# RMSDs for PDB wt compared to 1lz1
DATA_PATH = DATA_PATH_ROOT + '/data/results_rmsd/results_rmsd_pdb/results_rmsd_P61626_wt/'
dir_list = os.listdir(DATA_PATH)
rmsd_list_pdb_wt = np.zeros(len(dir_list))

for i in range(len(dir_list)):
    if i == 20 or i == 26:
        continue
    df = pd.read_csv(DATA_PATH + dir_list[i])['rmsd'][0]
    rmsd_list_pdb_wt[i] = df
pdb_wt_mean = np.mean(rmsd_list_pdb_wt)

# %%
# RMSD plot: AF2 vs. PDB
plt.title('P61626',fontsize=8)
plt.ylabel('X-ray $\chi_1$ [$^\circ$]',fontsize=8)
plt.xlabel('AF2 $\chi_1$ [$^\circ$]',fontsize=8)
trend = np.polyfit(af2_rmsd_list,pdb_rmsd_list,1)
trendpoly = np.poly1d(trend) 
plt.scatter(af2_rmsd_list, pdb_rmsd_list)
plt.plot(af2_rmsd_list,trendpoly(af2_rmsd_list), c='black', label = r'$\rho = 0.22$')
plt.legend(fontsize=14)
plt.savefig(DATA_PATH_ROOT + '/notebooks/figs/rmsd_P61626.png', dpi=1200, bbox_inches = 'tight')
correlations_vector(af2_rmsd_list, pdb_rmsd_list)
# Out:
# Pearson's correlation coefficient between data:  0.2206266173321082
# Spearman's correlation coefficient bewteen data:  0.3464384828862165
# [0.2206266173321082, 0.3464384828862165]

# %%
# Create histogram of RMSDs
output_variance_np = np.asarray(af2_rmsd_list)
hist,bin_edges = np.histogram(af2_rmsd_list)
weights = np.ones_like(af2_rmsd_list) / len(af2_rmsd_list)
n, bins, patches = plt.hist(af2_rmsd_list, 50, weights = weights, facecolor='lightblue', edgecolor='k', alpha=0.75)
plt.grid(axis='y', alpha=0.75)
plt.xlabel(r'RMSD C$\alpha$ [Å])',fontsize=8)
plt.ylabel('Frequency',fontsize=8)
plt.xticks(fontsize=8,rotation='vertical')
plt.yticks(fontsize=8)
plt.ylabel('Frequency',fontsize=8)
plt.title('P61626: RMSD of wild type and mutants',fontsize=8)
plt.axvline(np.mean(af2_rmsd_list), color='b', linestyle='dashed', linewidth=2)
#plt.savefig('/Users/holgerchristiannyelandehlers/Desktop/master_thesis/notebooks/figs/rmsd_dis_P0A7Y4.png', dpi=1200)

# %%
# Concat dataframes
df_af2 = pd.DataFrame (af2_rmsd_list, columns = ['rmsd_af2'])
df_pdb = pd.DataFrame (pdb_rmsd_list, columns = ['rmsd_pdb'])
df_mut2mut = pd.DataFrame (mut_2_mut_rmsd_list, columns = ['rmsd'])
df_mut2wt = pd.DataFrame (mut_2_wt_rmsd_list, columns = ['rmsd'])
df_concated = pd.concat([df_af2, df_pdb], axis=1)
a = dict(zip(np.unique(df_concated.rmsd_af2), np.array(['g','skyblue'])))
#df_concated.describe()

# %%
sns.histplot(df_pdb,x="rmsd_pdb", binwidth=0.01, alpha=0.75, kde=True, color="lightgrey", label="X-rayM2W: $\mu = {}$, $\sigma = {}$".format(round(df_pdb["rmsd_pdb"].mean(),3),round(df_pdb["rmsd_pdb"].std(),3)))
sns.histplot(df_af2, x="rmsd_af2", binwidth=0.01, alpha=0.75, kde=True, color='lightblue', label="AF2M2W: $\mu = {}$, $\sigma = {}$".format(round(df_af2["rmsd_af2"].mean(),3),round(df_af2["rmsd_af2"].std(),3)))
sns.histplot(df_mut2mut,x="rmsd", binwidth=0.01, alpha=0.75, kde=True, color="lightyellow", label="AF2M2M: $\mu = {}$, $\sigma = {}$".format(round(df_mut2mut["rmsd"].mean(),3),round(df_mut2mut["rmsd"].std(),3)))
sns.histplot(df_mut2wt, x="rmsd", binwidth=0.01, alpha=0.75, kde=True, color='lightgreen', label="AF2M2W: $\mu = {}$, $\sigma = {}$".format(round(df_mut2wt["rmsd"].mean(),3),round(df_mut2wt["rmsd"].std(),3)))


#sns.histplot(df_pdb, x="rmsd_pdb", binwidth=0.05, alpha=0.75, kde=True, color='lightblue', label="X-ray, $\mu = {}$, $\sigma = {}$".format(round(df_pdb["rmsd_pdb"].mean(),3),round(df_pdb["rmsd_pdb"].std(),3)))

plt.legend(fontsize=8)
plt.title('P61626: RMSD calculated using ChimeraX Matchmaker',fontsize=8)
plt.xlabel("RMSD [Å]")
plt.ylabel("Count")
plt.savefig(DATA_PATH_ROOT + "/notebooks/figs/P61626_dis.pdf")
plt.show()

# %%
mean_af2 = round(df_pdb["rmsd_pdb"].mean(),3)
std_af2= round(df_af2["rmsd_af2"].std(),3)

# %%
df_pdb['rmsd_pdb'].mean()
# Out:
# 0.27518948759919265

# %%
# Define consts
DATA_PATH_MUT_AF2_2wt = DATA_PATH_ROOT + '/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/'
DATA_PATH_MUT_PDB_2mut = DATA_PATH_ROOT + '/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2mut/'
DATA_PATH_PDB = DATA_PATH_ROOT + '/data/arodz12/pdbs_P61626/'
DATA_PATH_AF2 = DATA_PATH_ROOT + '/data/results_af2/P61626/'
arodz_pdbs = ['1gb5', '1gb6', '1gb7', '1gb8', '1gb9', '1gbo', '1gbw', '1gbx', '1gby', '1gbz', '1gfh', '1gfj', '1gfk', '1gfr', '1gft', '1gfu','1gfv', '1inu', '1lhh', '1lhi', '1lhj', '1lhk', '1lhl', '1oub','1ouc', '1oud', '1oue', '1ouh', '1oui', '1ouj', '1wqm', '1wqn','1wqo', '1wqp', '1wqq', '1wqr', '1yam', '1yan', '1yao', '1yap','1yaq', '2hea', '2heb', '2hec', '2hed', '2hee', '2hef']

# Get RMSDs
#af2_rmsd_list_2wt, mut = load_rmsd(DATA_PATH_MUT_AF2_2wt, arodz_pdbs)
pdb_rmsd_list_2mut, _ = load_rmsd(DATA_PATH_MUT_PDB_2mut, arodz_pdbs)
dir_list = sorted(os.listdir(DATA_PATH_MUT_AF2_2wt))
print(dir_list)
af2_rmsd_list_2wt = np.zeros(len(dir_list))
mut_list = [0]*len(dir_list)
for i in range(len(dir_list)):
    print(DATA_PATH_MUT_AF2_2wt)
    try:
        df = pd.read_csv(DATA_PATH_MUT_AF2_2wt + dir_list[i])['rmsd'][0]
        af2_rmsd_list_2wt[i] = df
    except TypeError:
        print('Could not load RMSD of {}'.format(dir_list[i]))
# Out:
# ['rmsd_mut2wt_P61626_1gb5.csv', 'rmsd_mut2wt_P61626_1gb6.csv', 'rmsd_mut2wt_P61626_1gb7.csv', 'rmsd_mut2wt_P61626_1gb8.csv', 'rmsd_mut2wt_P61626_1gb9.csv', 'rmsd_mut2wt_P61626_1gbo.csv', 'rmsd_mut2wt_P61626_1gbw.csv', 'rmsd_mut2wt_P61626_1gbx.csv', 'rmsd_mut2wt_P61626_1gby.csv', 'rmsd_mut2wt_P61626_1gbz.csv', 'rmsd_mut2wt_P61626_1gfh.csv', 'rmsd_mut2wt_P61626_1gfj.csv', 'rmsd_mut2wt_P61626_1gfk.csv', 'rmsd_mut2wt_P61626_1gfr.csv', 'rmsd_mut2wt_P61626_1gft.csv', 'rmsd_mut2wt_P61626_1gfu.csv', 'rmsd_mut2wt_P61626_1gfv.csv', 'rmsd_mut2wt_P61626_1inu.csv', 'rmsd_mut2wt_P61626_1lhh.csv', 'rmsd_mut2wt_P61626_1lhi.csv', 'rmsd_mut2wt_P61626_1lhj.csv', 'rmsd_mut2wt_P61626_1lhk.csv', 'rmsd_mut2wt_P61626_1lhl.csv', 'rmsd_mut2wt_P61626_1oub.csv', 'rmsd_mut2wt_P61626_1ouc.csv', 'rmsd_mut2wt_P61626_1oud.csv', 'rmsd_mut2wt_P61626_1oue.csv', 'rmsd_mut2wt_P61626_1ouh.csv', 'rmsd_mut2wt_P61626_1oui.csv', 'rmsd_mut2wt_P61626_1ouj.csv', 'rmsd_mut2wt_P61626_1wqm.csv', 'rmsd_mut2wt_P61626_1wqn.csv', 'rmsd_mut2wt_P61626_1wqo.csv', 'rmsd_mut2wt_P61626_1wqp.csv', 'rmsd_mut2wt_P61626_1wqq.csv', 'rmsd_mut2wt_P61626_1wqr.csv', 'rmsd_mut2wt_P61626_1yam.csv', 'rmsd_mut2wt_P61626_1yan.csv', 'rmsd_mut2wt_P61626_1yao.csv', 'rmsd_mut2wt_P61626_1yap.csv', 'rmsd_mut2wt_P61626_1yaq.csv', 'rmsd_mut2wt_P61626_2hea.csv', 'rmsd_mut2wt_P61626_2heb.csv', 'rmsd_mut2wt_P61626_2hec.csv', 'rmsd_mut2wt_P61626_2hed.csv', 'rmsd_mut2wt_P61626_2hee.csv', 'rmsd_mut2wt_P61626_2hef.csv']
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/
# /Users/holger/Desktop/master_thesis/data/results_rmsd/results_rmsd_af2/results_rmsd_P61626_mut2wt/

# %%
# RMSD plot: AF2 vs. PDB
plt.ylabel('Wild-type RMSD [Å]',fontsize=8)
plt.xlabel('Variant RMSD [Å]',fontsize=8)
trend = np.polyfit(pdb_rmsd_list_2mut,af2_rmsd_list_2wt,1)
trendpoly = np.poly1d(trend) 
plt.text(0.5, 0.5,'ρ = 0.88', size=12)
plt.scatter(pdb_rmsd_list_2mut, af2_rmsd_list_2wt)
plt.plot(pdb_rmsd_list_2mut,trendpoly(pdb_rmsd_list_2mut), c='black')
plt.savefig(DATA_PATH_ROOT + "/notebooks/figs/rmsd_plot_P61626_af2_vs_mut_wt.pdf", dpi=1200)
correlations_vector(pdb_rmsd_list_2mut, af2_rmsd_list_2wt)
# Out:
# Pearson's correlation coefficient between data:  0.8757960275067453
# Spearman's correlation coefficient bewteen data:  0.4009019426456984
# [0.8757960275067453, 0.4009019426456984]

# %%
print(df_af2["rmsd_af2"].mean())
print(df_pdb['rmsd_pdb'].mean())
# Out:
# 0.08072991330462809
# 0.27518948759919265
