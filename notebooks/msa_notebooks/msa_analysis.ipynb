# %%
import pandas as pd
import os

# %%
# Get the list of all files in the directory
DATA_PATH = '/Users/holger/Desktop/master_thesis/data/results_msa/P61626/'
file_list = os.listdir(DATA_PATH)

# Create an empty dataframe
df = pd.DataFrame()

# Iterate over all the files
for file in file_list:
    # Only read CSV files
    if file.endswith('.csv'):
        # Read the file
        temp_df = pd.read_csv(DATA_PATH + file)
        # Append the data to the main dataframe
        df = df.append(temp_df, ignore_index=True)
# Out:
# /var/folders/38/bl4yf01j4jx6h6m2ctkbjd3r0000gn/T/ipykernel_80566/342057570.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df, ignore_index=True)
# /var/folders/38/bl4yf01j4jx6h6m2ctkbjd3r0000gn/T/ipykernel_80566/342057570.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df, ignore_index=True)
# /var/folders/38/bl4yf01j4jx6h6m2ctkbjd3r0000gn/T/ipykernel_80566/342057570.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df, ignore_index=True)
# ...

# %%
df_stats = df.describe()

# %%
print(
    df_stats.round(1).to_latex(
        label="tab:msa_depth_stat",
        caption="Sample statistics of MSA for P61626",
    )
)
# Out:
# \begin{table}
# \centering
# \caption{Sample statistics of MSA for P61626}
# \label{tab:msa_depth_stat}
# \begin{tabular}{lrr}
# \toprule
# {} &  Unnamed: 0 &  msa\_depth \\
# \midrule
# count &        83.0 &       83.0 \\
# mean  &         0.0 &     4915.3 \\
# std   &         0.0 &       56.3 \\
# min   &         0.0 &     4597.0 \\
# 25\%   &         0.0 &     4911.0 \\
# 50\%   &         0.0 &     4933.0 \\
# 75\%   &         0.0 &     4933.0 \\
# max   &         0.0 &     4990.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
# /var/folders/38/bl4yf01j4jx6h6m2ctkbjd3r0000gn/T/ipykernel_80566/4257249633.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   df_stats.round(1).to_latex(

# %%
# Get the list of all files in the directory
DATA_PATH = '/Users/holger/Desktop/master_thesis/data/results_msa/P00720/'
file_list = os.listdir(DATA_PATH)

# Create an empty dataframe
df = pd.DataFrame()

# Iterate over all the files
for file in file_list:
    # Only read CSV files
    if file.endswith('.csv'):
        # Read the file
        temp_df = pd.read_csv(DATA_PATH + file)
        # Append the data to the main dataframe
        df = df.append(temp_df, ignore_index=True)
# Out:
# /var/folders/38/bl4yf01j4jx6h6m2ctkbjd3r0000gn/T/ipykernel_80566/1670138580.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df, ignore_index=True)
# /var/folders/38/bl4yf01j4jx6h6m2ctkbjd3r0000gn/T/ipykernel_80566/1670138580.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df, ignore_index=True)
# /var/folders/38/bl4yf01j4jx6h6m2ctkbjd3r0000gn/T/ipykernel_80566/1670138580.py:15: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df, ignore_index=True)
# ...

# %%
df_stats = df.describe()

# %%
print(
    df_stats.round(1).to_latex(
        label="tab:msa_depth_stat",
        caption="Sample statistics of MSA for P00720",
    )
)
# Out:
# \begin{table}
# \centering
# \caption{Sample statistics of MSA for P61626}
# \label{tab:msa_depth_stat}
# \begin{tabular}{lrr}
# \toprule
# {} &  Unnamed: 0 &  msa\_depth \\
# \midrule
# count &        59.0 &       59.0 \\
# mean  &         0.0 &     4324.8 \\
# std   &         0.0 &      157.4 \\
# min   &         0.0 &     3591.0 \\
# 25\%   &         0.0 &     4248.5 \\
# 50\%   &         0.0 &     4361.0 \\
# 75\%   &         0.0 &     4415.5 \\
# max   &         0.0 &     4596.0 \\
# \bottomrule
# \end{tabular}
# \end{table}
# /var/folders/38/bl4yf01j4jx6h6m2ctkbjd3r0000gn/T/ipykernel_80566/4257249633.py:2: FutureWarning: In future versions `DataFrame.to_latex` is expected to utilise the base implementation of `Styler.to_latex` for formatting and rendering. The arguments signature may therefore change. It is recommended instead to use `DataFrame.style.to_latex` which also contains additional functionality.
#   df_stats.round(1).to_latex(
